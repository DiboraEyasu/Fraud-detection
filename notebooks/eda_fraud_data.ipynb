# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

# %%
from scripts.EDA import EDAAnalyzer

# %% [markdown]
# ##### Load data

# %%
data_path = "C:\\Users\\ourbarn\\Desktop\\Fraud-detection\\data\\raw\\Fraud_Data.csv"

# %%
fraud_df = EDAAnalyzer(data_path)
# Out:
# 🔍🔍 Loading data...
# ✅✅ Data loaded successfully.

# %%
fraud_df.inspect_data()
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  object
#  2   purchase_time   151112 non-null  object
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.7+ MB
# None
#
# Missing Values:
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# ...

# %% [markdown]
# As expected in many fraud related datas, there are no null or missing values and duplicates.
# Since we don't have any missing or duplicated values, we will just pass with out dropping and imputing.

# %% [markdown]
# Correcting Datatypes

# %%
fraud_df.dtype_converter()
# Out:
# Converted the datatype of the specified columns successfully

# %% [markdown]
# ## Exploratory Data Analysis

# %%
key_variables = ['signup_time', 'purchase_time', 'purchase_value', 'source', 'age', 'sex', 'class', 'browser']

# %%
fraud_df.visualize_distribution(key_columns=key_variables)

# %%
fraud_df.visualize_relationship(x_col='class', y_col='purchase_value')
# Out:
# c:\Users\ourbarn\Desktop\Fraud-detection\scripts\EDA.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[0], x=self.data[x_col], y=self.data[y_col], palette='magma')
# c:\Users\ourbarn\Desktop\Fraud-detection\scripts\EDA.py:84: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1], x=self.data[x_col], y=self.data[y_col], palette='viridis')

# %%
fraud_df.visualize_relationship(x_col='class', y_col= 'browser')
# Out:
# c:\Users\ourbarn\Desktop\Fraud-detection\scripts\EDA.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[0], x=self.data[x_col], y=self.data[y_col], palette='magma')
# c:\Users\ourbarn\Desktop\Fraud-detection\scripts\EDA.py:84: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1], x=self.data[x_col], y=self.data[y_col], palette='viridis')
